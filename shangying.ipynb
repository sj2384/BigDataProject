# %%
import pandas as pd
import numpy as np
import os
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
import math
from PIL import Image
import random

# %% [markdown]
# # Wordcloud

# %%
text2 = open('D:/Courses/DSGA1004/gg/wordcloud/wordcloud.out').read()
stopwords = set(STOPWORDS)
stopwords.add("A.B.C")
wc = WordCloud(background_color="white", max_words=2000, stopwords=stopwords)
wc.generate(text2)
plt.imshow(wc, interpolation=None)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


nyccoloring = np.array(Image.open('D:/Courses/DSGA1004/gg/wordcloud/nyc_capture.png'))
text = open('D:/Courses/DSGA1004/gg/wordcloud/wordcloud.out').read()
stopwords = set(STOPWORDS)

wc = WordCloud(background_color="white", max_words=10000,mask=nyccoloring,
               stopwords=stopwords, random_state=5)
# generate word cloud
wc.generate(text)
image_colors = ImageColorGenerator(nyccoloring)
#wc.to_file('D:/Courses/DSGA1004/gg/wordcloud/NYC_Crime_Report.png')
wc.recolor(color_func=image_colors).to_file('D:/Courses/DSGA1004/gg/wordcloud/NYC_Crime_Report.png')
# create coloring from image


# show
#plt.imshow(wc, interpolation="bilinear")
#plt.axis("off")
#plt.show()
# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor

plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.figure()
plt.imshow(nyccoloring, cmap=plt.cm.gray, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # Stacked area plot

# %%
data = open('D:/Courses/DSGA1004/gg/year/2006.out').read()

# %%
with open('D:/Courses/DSGA1004/gg/year/2006.out', "r") as f:
    for line in f:
            key, values = line.split('\t')
            print(key, values)
# Out:
# BAIL JUMPING 1 & 2 44
#
# CHECK,BAD 76
#
# DRUG PARAPHERNALIA,   POSSESSE 174
#
# GENERAL BUSINESS LAW,TICKET SP 41
#
# HEALTH CODE,UNCLASSIFIED MISDE 2
#
# IMPRISONMENT 2,UNLAWFUL 144
#
# NY STATE LAWS,UNCLASSIFIED VIO 17
#
# PROSTITUTION 2, COMPULSORY 2
#
# ROBBERY, CHAIN STORE 307
#
# ROBBERY,POCKETBOOK/CARRIED BAG 671
#
# TRESPASS 1,CRIMINAL 382
#
#  567
#
# ARSON 2,3,4 1102
#
# BURGLARY,COMMERCIAL,DAY 1779
#
# FORGERY,M.V. REGISTRATION 544
#
# IMPRISONMENT 1,UNLAWFUL 118
#
# LARCENY,GRAND BY THEFT OF CREDIT CARD 5727
#
# LARCENY,GRAND OF AUTO 14734
#
# LARCENY,PETIT OF MOTORCYCLE 14
#
# ROBBERY,BICYCLE 114
#
# SEXUAL ABUSE 25
#
# CRIMINAL MISCHIEF,UNCLASSIFIED 4 17271
#
# LARCENY,GRAND BY FALSE PROMISE-NOT IN PERSON CONTACT 1
#
# LARCENY,PETIT FROM TRUCK 223
#
# LOITERING FOR PROSTITUTION OR 2
#
# MARIJUANA, POSSESSION 4 & 5 14886
#
# PRIVACY,OFFENSES AGAINST,UNCLA 1
#
# PUBLIC ADMINISTRATION,UNCLASSI 258
#
# WEAPONS,PROHIBITED USE IMITATI 1
#
# ...

# %%
with open('D:/Courses/DSGA1004/gg/boros/brooklyn0615.out', "r") as f1:
    brooklyn = {}
    for line in f1:
        key, values = line.split('\t')
        brooklyn[key] = int(values.strip('\n'))
        #print (key, values)

with open('D:/Courses/DSGA1004/gg/boros/bronx0615.out', "r") as f2:
    bronx = {}
    for line in f2:
        key, values = line.split('\t')
        bronx[key] = int(values.strip('\n'))
        #print (key, values)
        
with open('D:/Courses/DSGA1004/gg/boros/manhattan0615.out', "r") as f3:
    manhattan = {}
    for line in f3:
        key, values = line.split('\t')
        manhattan[key] = int(values.strip('\n'))
        #print (key, values)
        
with open('D:/Courses/DSGA1004/gg/boros/queen0615.out', "r") as f4:
    queen = {}
    for line in f4:
        key, values = line.split('\t')
        queen[key] = int(values.strip('\n'))
        #print (key, values)
        
with open('D:/Courses/DSGA1004/gg/boros/staten0615.out', "r") as f5:
    staten = {}
    for line in f5:
        key, values = line.split('\t')
        staten[key] = int(values.strip('\n'))
        #print (key, values)

# %%
year = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']

# %%
brooklyn0615 = []
bronx0615 = []
manhattan0615 = []
queen0615 = []
staten0615 = []

for key in year:
    brooklyn0615.append(brooklyn[key])
    bronx0615.append(bronx[key])
    manhattan0615.append(manhattan[key])
    queen0615.append(queen[key])
    staten0615.append(staten[key])

# %%
queen0615
# Out:
# [107170, 106393, 103266, 98917, 99436, 98640, 99080, 100908, 100087, 92981]

# %%
bronx0615
# Out:
# [114328,
#  117561,
#  114235,
#  112795,
#  112169,
#  108765,
#  106883,
#  104062,
#  106016,
#  102950]

# %%
brooklyn0615
# Out:
# [160029,
#  156347,
#  155912,
#  150486,
#  152342,
#  151808,
#  154690,
#  149559,
#  148453,
#  140351]

# %%
manhattan0615
# Out:
# [129603,
#  130743,
#  128380,
#  124574,
#  121668,
#  115687,
#  119863,
#  117742,
#  113095,
#  110580]

# %%
staten0615
# Out:
# [27542, 26156, 26881, 24173, 24109, 23297, 23611, 22612, 22711, 21714]

# %%
#need to first pip install plotly 
#follow instrcution: https://plot.ly/python/getting-started/

import plotly.plotly as py
import plotly.graph_objs as go

# %%
brooklyn1 = go.Scatter(
    x=year,
    y=brooklyn0615,
    name='brooklyn',
    #mode='lines',
    #line=dict(width=0.5,color='rgb(184, 247, 212)'),
    fill='tonexty'
)
bronx1 = go.Scatter(
    x=year,
    y=bronx0615,
    name='bronx',
    #mode='lines',
    #line=dict(width=0.5,color='rgb(111, 231, 219)'),
    fill='tonexty'
)
manhattan1 = go.Scatter(
    x=year,
    y=manhattan0615,
    name='manhattan',
    #mode='lines',
    #line=dict(width=0.5,color='rgb(127, 166, 238)'),
    fill='tonexty'
)
queen1 = go.Scatter(
    x=year,
    y=queen0615,
    name='queen',
    #mode='lines',
    #line=dict(width=0.5,color='rgb(131, 90, 241)'),
    fill='tonexty'
)
staten1 = go.Scatter(
    x=year,
    y=staten0615,
    name='staten',
    #mode='lines',
    #line=dict(width=0.5,color='rgb(143, 19, 131)'),
    fill='tonexty'
)

data = [brooklyn1, bronx1, manhattan1, queen1, staten1]
layout = go.Layout(
    showlegend=True,
    xaxis=dict(
        type='category',
    ),
    yaxis=dict(
        type='linear',
        range=[1, 100],
        dtick=20,
        ticksuffix='%'
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(data, filename = 'basic-line')
help(py.plot)
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~hotgt930/0 or inside your plot.ly account where it is named 'basic-line'
# Help on function plot in module plotly.plotly.plotly:
#
# plot(figure_or_data, validate=True, **plot_options)
#     Create a unique url for this plot in Plotly and optionally open url.
#
#     plot_options keyword agruments:
#     filename (string) -- the name that will be associated with this figure
#     fileopt ('new' | 'overwrite' | 'extend' | 'append') -- 'new' creates a
#         'new': create a new, unique url for this plot
#         'overwrite': overwrite the file associated with `filename` with this
#         'extend': add additional numbers (data) to existing traces
#         'append': add additional traces to existing data lists
#     auto_open (default=True) -- Toggle browser options
#         True: open this plot in a new browser tab
# ...

# %%
boro_ppl = pd.read_csv('D:/Courses/DSGA1004/project/boro_population.csv')

# %%
boro_ppl
# Out:
#     year           boro  population  counts
# 0   2006          bronx     1362930  114328
# 1   2007          bronx     1368382  117561
# 2   2008          bronx     1373855  114235
# 3   2009          bronx     1379351  112795
# 4   2010          bronx     1384868  112169
# 5   2011          bronx     1400000  108765
# 6   2012          bronx     1415000  106883
# 7   2013          bronx     1429000  104062
# 8   2014          bronx     1442000  106016
# 9   2015          bronx     1455000  102950
# 10  2006       brooklyn     2489598  160029
# 11  2007       brooklyn     2493553  156347
# 12  2008       brooklyn     2497515  155912
# 13  2009       brooklyn     2501482  150486
# 14  2010       brooklyn     2505456  152342
# 15  2011       brooklyn     2545000  151808
# 16  2012       brooklyn     2574000  154690
# 17  2013       brooklyn     2600000  149559
# 18  2014       brooklyn     2621000  148453
# 19  2015       brooklyn     2637000  140351
# ...

# %%
sns_plot = sns.jointplot(x=boro_ppl['population'], y=boro_ppl['counts'], kind="reg")
sns_plot.savefig("D:/Courses/DSGA1004/gg/Correlation/boro_population_output.png",dpi=1000)
# Out:
# C:\Users\sj238\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# # Pie plot of offense level

# %%
outputs = os.listdir('D:/Courses/DSGA1004/gg/offense_lv')
outputs = [f for f in outputs if f[-3:]=='out']

# %%
offense_lv = ['VIOLATION','FELONY','MISDEMEANOR']
def to_list (filename,key_list):
    with open(filename, "r") as f:
        D = {}
        listname = []
        for line in f:
            key, values = line.split('\t')
            D[key] = int(values.strip('\n'))
        for k in key_list:
            listname.append(D[k])
        return listname

# %%
to_list ('D:/Courses/DSGA1004/gg/offense_lv/offense_lv_jan.out',offense_lv)
# Out:
# [48089, 129477, 238507]

# %%
#month = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','total']
for file in outputs:
    if file[-7:-4] == 'jan':
        jan = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'feb':
        feb = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'mar':
        mar = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'apr':
        apr = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'may':
        may = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'jun':
        jun = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'jul':
        jul = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'aug':
        aug = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'sep':
        sep = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'oct':
        Oct = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'nov':
        nov = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    if file[-7:-4] == 'dec':
        dec = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)
    else:
        total = to_list('D:/Courses/DSGA1004/gg/offense_lv/'+file,offense_lv)

# %%
monlist = [jan,feb,mar,apr,may,jun,jul,aug,sep,Oct,nov,dec,total]
month = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','total']

# %%
monlist = [jan,feb,mar,apr,may,jun,jul,aug,sep,Oct,nov,dec,total]

# %%
def plot_pie(monlist, month):
    colors = ['gold', 'yellowgreen', 'lightskyblue']
    plt.pie(monlist, labels=offense_lv, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
    plt.axis('equal')
    plt.title('offense of ' + month)
    plt.savefig('D:/Courses/DSGA1004/gg/offense_lv/'+month+'.png', format='png',dpi = 1000)
    plt.show()

# %%
for x,y in zip(monlist, month):
    plot_pie(x,y)

# %% [markdown]
# ## NYCHA VS. NON-NYCHA

# %%
nycha_list = to_list('D:/Courses/DSGA1004/project/offense_lv/HAD.out',offense_lv)
nonha_list = to_list('D:/Courses/DSGA1004/project/offense_lv/no_HAD.out',offense_lv)

# %%
value_list = [nonha_list, nycha_list]

# %%
keys = ['HAD','NON-HAD']

# %%
colors = ['gold', 'yellowgreen', 'lightskyblue']
plt.pie(nycha_list, labels=offense_lv, colors=colors,
    autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('offense of NYCHA')
plt.savefig('D:/Courses/DSGA1004/project/offense_lv/NYCHA_offense_lv.png', format='png')
plt.show()

# %%
colors = ['gold', 'yellowgreen', 'lightskyblue']
plt.pie(nonha_list, labels=offense_lv, colors=colors,
    autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('offense of NON-NYCHA')
plt.savefig('D:/Courses/DSGA1004/project/offense_lv/NON-NYCHA_offense_lv.png', format='png')
plt.show()

# %% [markdown]
# # Top 20 offense types

# %%
yearout = os.listdir('D:/Courses/DSGA1004/gg/year')
yearout = [f for f in yearout if f[-3:]=='out']

# %%
yearout
# Out:
# ['2006.out',
#  '2007.out',
#  '2008.out',
#  '2009.out',
#  '2010.out',
#  '2011.out',
#  '2012.out',
#  '2013.out',
#  '2014.out',
#  '2015.out']

# %%
def to_dict(filename):
    with open(filename, "r") as f:
        D = {}
        for line in f:
            key, values = line.split('\t')
            D[key] = int(values.strip('\n'))
        return D

# %%
top20 = to_dict('D:/Courses/DSGA1004/gg/top20/top20.out')

# %%
for file in yearout:
    y = file[:4]
    if y == '2006':
        dict2006 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2007':
        dict2007 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2008':
        dict2008 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2009':
        dict2009 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2010':
        dict2010 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2011':
        dict2011 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2012':
        dict2012 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2013':
        dict2013 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2014':
        dict2014 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)
    if y == '2015':
        dict2015 = to_dict('D:/Courses/DSGA1004/gg/year/'+file)

# %%
top20.keys()
# Out:
# dict_keys(['LARCENY,PETIT FROM AUTO', 'CRIMINAL MISCHIEF 4TH, GRAFFIT', 'LARCENY,GRAND OF AUTO', 'HARASSMENT,SUBD 1,CIVILIAN', 'MARIJUANA, POSSESSION 4 & 5', 'ASSAULT 2,1,UNCLASSIFIED', 'ASSAULT 3', 'HARASSMENT,SUBD 3,4,5', 'CRIMINAL MISCHIEF,UNCLASSIFIED 4', 'LARCENY,PETIT FROM OPEN AREAS,', 'WEAPONS, POSSESSION, ETC', 'ROBBERY,OPEN AREA UNCLASSIFIED', 'MISCHIEF, CRIMINAL 4, OF MOTOR', 'BURGLARY,RESIDENCE,DAY', 'LARCENY,GRAND FROM BUILDING (NON-RESIDENCE) UNATTENDED', 'AGGRAVATED HARASSMENT 2', 'LARCENY,PETIT FROM BUILDING,UN', 'CONTROLLED SUBSTANCE, POSSESSI', 'LARCENY,PETIT FROM STORE-SHOPL', 'INTOXICATED DRIVING,ALCOHOL'])

# %%
def dict_filter(in_dict,filt_dict):
    DD = { k: in_dict[k] for k in filt_dict.keys() }
    return DD

# %%
dict2006 =  dict_filter(dict2006,top20)
dict2007 =  dict_filter(dict2007,top20)
dict2008 =  dict_filter(dict2008,top20)
dict2009 =  dict_filter(dict2009,top20)
dict2010 =  dict_filter(dict2010,top20)
dict2011 =  dict_filter(dict2011,top20)
dict2012 =  dict_filter(dict2012,top20)
dict2013 =  dict_filter(dict2013,top20)
dict2014 =  dict_filter(dict2014,top20)
dict2015 =  dict_filter(dict2015,top20)

# %%
cols = ['top20_type'] + year

# %%
df2 = pd.DataFrame(columns=cols)

# %%
df2.columns
# Out:
# Index(['top20_type', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
cnt = 0
for k in top20.keys():
    df2.loc[cnt, 'top20_type'] = k
    df2.loc[cnt, '2006'] = dict2006[k] 
    df2.loc[cnt, '2007'] = dict2007[k]
    df2.loc[cnt, '2008'] = dict2008[k]
    df2.loc[cnt, '2009'] = dict2009[k]
    df2.loc[cnt, '2010'] = dict2010[k]
    df2.loc[cnt, '2011'] = dict2011[k]
    df2.loc[cnt, '2012'] = dict2012[k]
    df2.loc[cnt, '2013'] = dict2013[k]
    df2.loc[cnt, '2014'] = dict2014[k]
    df2.loc[cnt, '2015'] = dict2015[k]
    cnt += 1

# %%
df2
# Out:
#                                            top20_type   2006   2007   2008  \
# 0                             LARCENY,PETIT FROM AUTO  19774  20783  22626
# 1                      CRIMINAL MISCHIEF 4TH, GRAFFIT   4751   8537   9568
# 2                               LARCENY,GRAND OF AUTO  14734  12111  11450
# 3                          HARASSMENT,SUBD 1,CIVILIAN  29369  28463  26023
# 4                         MARIJUANA, POSSESSION 4 & 5  14886  17357  18284
# 5                            ASSAULT 2,1,UNCLASSIFIED  15453  15546  14399
# 6                                           ASSAULT 3  43953  43877  43274
# 7                               HARASSMENT,SUBD 3,4,5  39401  36646  34982
# 8                    CRIMINAL MISCHIEF,UNCLASSIFIED 4  17271  16616  15448
# 9                      LARCENY,PETIT FROM OPEN AREAS,   8941   8029   7796
# 10                           WEAPONS, POSSESSION, ETC   7098   7713   7656
# ...

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
ax = df2.set_index('top20_type').transpose().plot.bar(stacked=True,legend=False)
ax.set_xticklabels(df4.index, rotation=0)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## NYCHA

# %%
nycha = to_dict('D:/Courses/DSGA1004/dumbo/project/nycha/nycha.out')

# %%
nycha_df = pd.read_csv('D:/Courses/DSGA1004/gg/NYCHA/NYCHA_Development_Data_Book.csv')

# %%
nycha_df.columns
# Out:
# Index(['﻿DATA AS OF', 'DEVELOPMENT', 'HUD AMP#', 'TDS#', 'CONSOLIDATED TDS#',
#        'DEVELOPMENT EDP#', 'OPERATING EDP#', 'HUD #', 'PROGRAM', 'METHOD',
#        'TYPE', 'NUMBER OF SECTION 8 TRANSITION APARTMENTS',
#        'NUMBER OF CURRENT APARTMENTS', 'TOTAL NUMBER OF APARTMENTS',
#        'NUMBER OF RENTAL ROOMS', 'AVG NO R/R PER APARTMENT',
#        'POPULATION SECTION 8 TRANSITION', 'POPULATION PUBLIC HOUSING',
#        'TOTAL POPULATION', 'NUMBER OF RESIDENTIAL BLDGS',
#        'NUMBER OF NON-RESIDENTIAL BLDGS', 'NUMBER OF STAIRHALLS',
#        'NUMBER OF STORIES', 'TOTAL AREA SQ FT', 'ACRES', 'NET DEV AREA SQ FT',
#        'EXCLUDING PARK ACRES', 'BLDG COVERAGE SQ FT', 'CUBAGE CU FT',
#        'BLDG COVERAGE %', 'DENSITY', 'DEVELOPMENT COST', 'PER RENTAL ROOM',
#        'AVG MONTHLY GROSS RENT', 'LOCATION STREET A', 'LOCATION STREET B',
#        'LOCATION STREET C', 'LOCATION STREET D', 'BOROUGH',
#        'COMMUNITY DISTIRCT', 'US CONGRESSIONAL DISTRICT',
# ...

# %%
nycha_df['DEVELOPMENT']
# Out:
# 0                        1010 EAST 178TH STREET
# 1                        104-14 TAPSCOTT STREET
# 2                   1162-1176 WASHINGTON AVENUE
# 3                     131 SAINT NICHOLAS AVENUE
# 4                            1471 WATSON AVENUE
# 5                          154 WEST 84TH STREET
# 6                             303 VERNON AVENUE
# 7                         335 EAST 111TH STREET
# 8                          344 EAST 28TH STREET
# 9                               45 ALLEN STREET
# 10                            572 WARREN STREET
# 11                         830 AMSTERDAM AVENUE
# 12                                        ADAMS
# 13                                       ALBANY
# 14                                    ALBANY II
# 15                                    AMSTERDAM
# 16                           AMSTERDAM ADDITION
# 17                                  ARMSTRONG I
# 18                                 ARMSTRONG II
# 19            FHA REPOSSESSED HOUSES (GROUP IV)
# ...

# %%
ha_df = pd.DataFrame(columns=['DEVELOPMENT','COUNTS'])
cnt = 0
for k in nycha.keys():
    ha_df.loc[cnt, 'DEVELOPMENT'] = k
    ha_df.loc[cnt, 'COUNTS'] = nycha[k]    
    cnt += 1

# %%
ha_df = ha_df.ix[1:]
ha_df
# Out:
#                             DEVELOPMENT COUNTS
# 1                           COOPER PARK   1473
# 2                  BRONX RIVER ADDITION     99
# 3                      PALMETTO GARDENS     30
# 4                               WOODSON    229
# 5                              FARRAGUT   3673
# 6                             BRONXDALE   3485
# 7                     HUGHES APARTMENTS   1727
# 8                    SOUTHERN BOULEVARD    100
# 9                       45 ALLEN STREET    111
# 10                          SOUTH BEACH   1109
# 11                 BOYNTON AVENUE REHAB    257
# 12                      JENNINGS STREET     44
# 13              EAST NEW YORK CITY LINE    217
# 14                                BROWN     12
# 15             MORRISANIA AIR RIGHTS 42    310
# 16                          VAN DYKE II     68
# 17                           LA GUARDIA   1985
# 18                       CAMPOS PLAZA I    311
# 19                          CASTLE HILL   5495
# ...

# %%
merge_df = pd.merge(ha_df,nycha_df,how='inner',on='DEVELOPMENT')

# %%
merge_df = merge_df[['DEVELOPMENT','COUNTS','TOTAL POPULATION','AVG MONTHLY GROSS RENT']]

# %%
merge_df['AVG MONTHLY GROSS RENT'] = merge_df['AVG MONTHLY GROSS RENT'].str.replace('$', '')
merge_df['AVG MONTHLY GROSS RENT'] = merge_df['AVG MONTHLY GROSS RENT'].astype(float)

# %%
merge_df['TOTAL POPULATION'] = merge_df['TOTAL POPULATION'].str.replace(',','')

# %%
merge_df= merge_df.dropna()

# %%
merge_df['TOTAL POPULATION'] = merge_df['TOTAL POPULATION'].astype(int)

# %%
merge_df['TOTAL POPULATION'][0]
# Out:
# 1578

# %%
merge_df['AVG MONTHLY GROSS RENT'][0]
# Out:
# 489.08999999999997

# %%
merge_df['COUNTS'].isnull().value_counts()
# Out:
# False    250
# Name: COUNTS, dtype: int64

# %%
merge_df
# Out:
#                             DEVELOPMENT COUNTS  TOTAL POPULATION  \
# 0                           COOPER PARK   1473              1578
# 1                  BRONX RIVER ADDITION     99               240
# 2                      PALMETTO GARDENS     30               117
# 3                               WOODSON    229               435
# 4                              FARRAGUT   3673              3277
# 5                     HUGHES APARTMENTS   1727              1418
# 6                       45 ALLEN STREET    111               241
# 7                           SOUTH BEACH   1109               932
# 8                  BOYNTON AVENUE REHAB    257               188
# 9               EAST NEW YORK CITY LINE    217               275
# 10                                BROWN     12               218
# 11                          VAN DYKE II     68               132
# 12                           LA GUARDIA   1985              2512
# ...

# %%
sns_plot = sns.jointplot(x=merge_df['TOTAL POPULATION'], y=merge_df['COUNTS'], kind="reg")
sns_plot.savefig("D:/Courses/DSGA1004/gg/Correlation/nycha_population_output.png",dpi=1000)
# Out:
# C:\Users\sj238\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns_plot = sns.jointplot(x=merge_df['AVG MONTHLY GROSS RENT'], y=merge_df['COUNTS'], kind="reg")
# Out:
# C:\Users\sj238\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ## NTA

# %%
nta_df = pd.read_csv('D:/Courses/DSGA1004/project/Merged_Data.csv')

# %%
nta_df
# Out:
#      Unnamed: 0                                                NTA  Count  \
# 0             0                            Allerton-Pelham Gardens  14091
# 1             1         Annadale-Huguenot-Prince's Bay-Eltingville   9225
# 2             2                                      Arden Heights   6532
# 3             3                                            Astoria  34609
# 4             4                                         Auburndale   5528
# 5             5                                       Baisley Park  22271
# 6             6                                         Bath Beach  11944
# 7             7                                          Bay Ridge  35817
# 8             8                              Bayside-Bayside Hills  13058
# 9             9                                            Bedford  53692
# 10           10                         Bedford Park-Fordham North  44154
# 11           11                                          Bellerose   7221
# ...

# %%
nta_df = nta_df.drop(['Unnamed: 0'],1)

# %%
nta_df.columns
# Out:
# Index(['NTA', 'Count', 'Male_Prct', 'Female_Prct', 'Med_Age', 'His_Prct',
#        'Wht_Prct', 'Blk_Prct', 'Asi_Prct', 'Unemp_Prct', 'Med_Icm', 'Ins_Prct',
#        'Bl_Pvt_Prct', 'M_Mrg_Prct', 'F_Mrg_Prct', 'Bf_Hs_Prct', 'Af_Hs_Prct',
#        'Vtr_Prct', 'Dis_Prct', 'Citi_Prct'],
#       dtype='object')

# %%
my_features = ['Male_Prct', 'Female_Prct', 'Med_Age', 'His_Prct',
               'Wht_Prct', 'Blk_Prct', 'Asi_Prct', 'Unemp_Prct', 'Med_Icm']

# %%
from scipy import stats

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(nta_df['Male_Prct'], nta_df['Count'])

# %%
slope
# Out:
# -52862.748529317425

# %%
import seaborn as sns; sns.set(color_codes=True)

# %%
#ax = sns.regplot(x=nta_df['Male_Prct'], y=nta_df['Count'], marker="+")

# %%
sns_plot = sns.jointplot(x=nta_df['Blk_Prct'], y=nta_df['Unemp_Prct'], kind="reg")
# Out:
# C:\Users\sj238\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns_plot.savefig("D:/Courses/DSGA1004/project/output.png",dpi=1000)

# %%
for i in my_features:
    sns_plot = sns.jointplot(x=nta_df[i], y=nta_df['Count'], kind="reg")
    sns_plot.savefig("D:/Courses/DSGA1004/gg/Correlation/" + i + "_output.png",dpi=1000)
# Out:
# C:\Users\sj238\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
